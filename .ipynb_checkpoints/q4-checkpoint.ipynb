# %% [markdown]
# Q4:
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
def is_palindrome(num):
    
    str_num = str(num)
    i = len(str_num)-1
    j = 0
    
    # Go from one end to the middle, comparing numbers
    while i > j:
        if str_num[i] != str_num[j]:
            return False
        
        i-=1
        j+=1
        
    return True

# %%
def find_mod(a, b):
    return a%b

def find_max_product(num):
    max_num = 999
    curr_max = 999
    mod = find_mod(num, curr_max)
    
    while mod != 0:
        curr_max -= 1
        mod = find_mod(num, curr_max)
    return curr_max, num/curr_max

# %%
max_pos_palindrome = 999*999
num_1 = 1
num_2 = 1

curr_palindrome = max_pos_palindrome

while len(str(num_1)) != 3 and len(str(num_2)) != 3:
    # Go until you find the largest palindrome
    while not is_palindrome(curr_palindrome):
        curr_palindrome -= 1

        max_plaindrome = curr_palindrome    

        num_1, num_2 = find_max_product(max_plaindrome)
        print("Num 1: " + str(num_1))
        print("Num 2: " + str(num_2))

        print("Palindrome: " + str(max_plaindrome))
# Out:
# Num 1: 998
# Num 2: 1000.0
# Palindrome: 998000
# Num 1: 311
# Num 2: 3209.0
# Palindrome: 997999
# Num 1: 282
# Num 2: 3539.0
# Palindrome: 997998
# Num 1: 997
# Num 2: 1001.0
# Palindrome: 997997
# Num 1: 4
# Num 2: 249499.0
# Palindrome: 997996
# Num 1: 15
# Num 2: 66533.0
# Palindrome: 997995
# Num 1: 38
# Num 2: 26263.0
# Palindrome: 997994
# Num 1: 23
# Num 2: 43391.0
# Palindrome: 997993
# Num 1: 996
# Num 2: 1002.0
# Palindrome: 997992
# Num 1: 1
# Num 2: 997991.0
# Palindrome: 997991
# Num 1: 742
# Num 2: 1345.0
# Palindrome: 997990
# Num 1: 321
# Num 2: 3109.0
# Palindrome: 997989
# Num 1: 4
# Num 2: 249497.0
# Palindrome: 997988
# Num 1: 43
# Num 2: 23209.0
# Palindrome: 997987
# Num 1: 66
# Num 2: 15121.0
# Palindrome: 997986
# Num 1: 995
# Num 2: 1003.0
# Palindrome: 997985
# Num 1: 416
# Num 2: 2399.0
# Palindrome: 997984
# Num 1: 657
# Num 2: 1519.0
# Palindrome: 997983
# Num 1: 458
# Num 2: 2179.0
# Palindrome: 997982
# Num 1: 241
# Num 2: 4141.0
# Palindrome: 997981
# Num 1: 60
# Num 2: 16633.0
# Palindrome: 997980
# Num 1: 467
# Num 2: 2137.0
# Palindrome: 997979
# Num 1: 2
# Num 2: 498989.0
# Palindrome: 997978
# Num 1: 87
# Num 2: 11471.0
# Palindrome: 997977
# Num 1: 994
# Num 2: 1004.0
# Palindrome: 997976
# Num 1: 955
# Num 2: 1045.0
# Palindrome: 997975
# Num 1: 54
# Num 2: 18481.0
# Palindrome: 997974
# Num 1: 1
# Num 2: 997973.0
# Palindrome: 997973
# Num 1: 719
# Num 2: 1388.0
# Palindrome: 997972
# Num 1: 39
# Num 2: 25589.0
# Palindrome: 997971
# Num 1: 230
# Num 2: 4339.0
# Palindrome: 997970
# Num 1: 7
# Num 2: 142567.0
# Palindrome: 997969
# Num 1: 816
# Num 2: 1223.0
# Palindrome: 997968
# Num 1: 103
# Num 2: 9689.0
# Palindrome: 997967
# Num 1: 254
# Num 2: 3929.0
# Palindrome: 997966
# Num 1: 993
# Num 2: 1005.0
# Palindrome: 997965
# Num 1: 814
# Num 2: 1226.0
# Palindrome: 997964
# Num 1: 1
# Num 2: 997963.0
# Palindrome: 997963
# Num 1: 42
# Num 2: 23761.0
# Palindrome: 997962
# Num 1: 1
# Num 2: 997961.0
# Palindrome: 997961
# Num 1: 818
# Num 2: 1220.0
# Palindrome: 997960
# Num 1: 453
# Num 2: 2203.0
# Palindrome: 997959
# Num 1: 586
# Num 2: 1703.0
# Palindrome: 997958
# Num 1: 89
# Num 2: 11213.0
# Palindrome: 997957
# Num 1: 684
# Num 2: 1459.0
# Palindrome: 997956
# Num 1: 35
# Num 2: 28513.0
# Palindrome: 997955
# Num 1: 2
# Num 2: 498977.0
# Palindrome: 997954
# Num 1: 33
# Num 2: 30241.0
# Palindrome: 997953
# Num 1: 992
# Num 2: 1006.0
# Palindrome: 997952
# Num 1: 799
# Num 2: 1249.0
# Palindrome: 997951
# Num 1: 150
# Num 2: 6653.0
# Palindrome: 997950
# Num 1: 1
# Num 2: 997949.0
# Palindrome: 997949
# Num 1: 812
# Num 2: 1229.0
# Palindrome: 997948
# Num 1: 621
# Num 2: 1607.0
# Palindrome: 997947
# Num 1: 2
# Num 2: 498973.0
# Palindrome: 997946
# Num 1: 845
# Num 2: 1181.0
# Palindrome: 997945
# Num 1: 967
# Num 2: 1032.0
# Palindrome: 997944
# Num 1: 773
# Num 2: 1291.0
# Palindrome: 997943
# Num 1: 22
# Num 2: 45361.0
# Palindrome: 997942
# Num 1: 21
# Num 2: 47521.0
# Palindrome: 997941
# Num 1: 820
# Num 2: 1217.0
# Palindrome: 997940
# Num 1: 233
# Num 2: 4283.0
# Palindrome: 997939
# Num 1: 18
# Num 2: 55441.0
# Palindrome: 997938
# Num 1: 991
# Num 2: 1007.0
# Palindrome: 997937
# Num 1: 776
# Num 2: 1286.0
# Palindrome: 997936
# Num 1: 15
# Num 2: 66529.0
# Palindrome: 997935
# Num 1: 833
# Num 2: 1198.0
# Palindrome: 997934
# Num 1: 1
# Num 2: 997933.0
# Palindrome: 997933
# Num 1: 156
# Num 2: 6397.0
# Palindrome: 997932
# Num 1: 353
# Num 2: 2827.0
# Palindrome: 997931
# Num 1: 10
# Num 2: 99793.0
# Palindrome: 997930
# Num 1: 9
# Num 2: 110881.0
# Palindrome: 997929
# Num 1: 632
# Num 2: 1579.0
# Palindrome: 997928
# Num 1: 259
# Num 2: 3853.0
# Palindrome: 997927
# Num 1: 354
# Num 2: 2819.0
# Palindrome: 997926
# Num 1: 895
# Num 2: 1115.0
# Palindrome: 997925
# Num 1: 92
# Num 2: 10847.0
# Palindrome: 997924
# Num 1: 3
# Num 2: 332641.0
# Palindrome: 997923
# Num 1: 2
# Num 2: 498961.0
# Palindrome: 997922
# Num 1: 31
# Num 2: 32191.0
# Palindrome: 997921
# Num 1: 990
# Num 2: 1008.0
# Palindrome: 997920
# Num 1: 377
# Num 2: 2647.0
# Palindrome: 997919
# Num 1: 38
# Num 2: 26261.0
# Palindrome: 997918
# Num 1: 867
# Num 2: 1151.0
# Palindrome: 997917
# Num 1: 787
# Num 2: 1268.0
# Palindrome: 997916
# Num 1: 5
# Num 2: 199583.0
# Palindrome: 997915
# Num 1: 6
# Num 2: 166319.0
# Palindrome: 997914
# Num 1: 7
# Num 2: 142559.0
# Palindrome: 997913
# Num 1: 8
# Num 2: 124739.0
# Palindrome: 997912
# Num 1: 9
# Num 2: 110879.0
# Palindrome: 997911
# Num 1: 730
# Num 2: 1367.0
# Palindrome: 997910
# Num 1: 913
# Num 2: 1093.0
# Palindrome: 997909
# Num 1: 822
# Num 2: 1214.0
# Palindrome: 997908
# Num 1: 379
# Num 2: 2633.0
# Palindrome: 997907
# Num 1: 182
# Num 2: 5483.0
# Palindrome: 997906
# Num 1: 937
# Num 2: 1065.0
# Palindrome: 997905
# Num 1: 752
# Num 2: 1327.0
# Palindrome: 997904
# Num 1: 113
# Num 2: 8831.0
# Palindrome: 997903
# Num 1: 18
# Num 2: 55439.0
# Palindrome: 997902
# Num 1: 989
# Num 2: 1009.0
# Palindrome: 997901
# Num 1: 850
# Num 2: 1174.0
# Palindrome: 997900
# Num 1: 861
# Num 2: 1159.0
# Palindrome: 997899
# Num 1: 737
# Num 2: 1354.0
# Palindrome: 997898
# Num 1: 1
# Num 2: 997897.0
# Palindrome: 997897
# Num 1: 24
# Num 2: 41579.0
# Palindrome: 997896
# Num 1: 545
# Num 2: 1831.0
# Palindrome: 997895
# Num 1: 2
# Num 2: 498947.0
# Palindrome: 997894
# Num 1: 351
# Num 2: 2843.0
# Palindrome: 997893
# Num 1: 908
# Num 2: 1099.0
# Palindrome: 997892
# Num 1: 1
# Num 2: 997891.0
# Palindrome: 997891
# Num 1: 930
# Num 2: 1073.0
# Palindrome: 997890
# Num 1: 1
# Num 2: 997889.0
# Palindrome: 997889
# Num 1: 512
# Num 2: 1949.0
# Palindrome: 997888
# Num 1: 363
# Num 2: 2749.0
# Palindrome: 997887
# Num 1: 326
# Num 2: 3061.0
# Palindrome: 997886
# Num 1: 245
# Num 2: 4073.0
# Palindrome: 997885
# Num 1: 954
# Num 2: 1046.0
# Palindrome: 997884
# Num 1: 17
# Num 2: 58699.0
# Palindrome: 997883
# Num 1: 214
# Num 2: 4663.0
# Palindrome: 997882
# Num 1: 417
# Num 2: 2393.0
# Palindrome: 997881
# Num 1: 988
# Num 2: 1010.0
# Palindrome: 997880
# Num 1: 1
# Num 2: 997879.0
# Palindrome: 997879
# Num 1: 966
# Num 2: 1033.0
# Palindrome: 997878
# Num 1: 1
# Num 2: 997877.0
# Palindrome: 997877
# Num 1: 44
# Num 2: 22679.0
# Palindrome: 997876
# Num 1: 887
# Num 2: 1125.0
